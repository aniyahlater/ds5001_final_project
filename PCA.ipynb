# %%
# going to import the necessary packages 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA, TruncatedSVD as SVD
import plotly_express as px 
import plotly.io as pio

# %% [markdown]
# # Loading in the data

# %%
LIB = pd.read_csv('/Users/aniyahmcwilliams/Spring 2026/Text As Data/final project/DATA/LIB.csv', index_col='mag_id')
TFIDF_raw = pd.read_csv('/Users/aniyahmcwilliams/Spring 2026/Text As Data/final project/DATA/TFIDF.csv',index_col='mag_id')
TFIDF = pd.DataFrame(normalize(TFIDF_raw, norm='l2', axis=1), index=TFIDF_raw.index, columns=TFIDF_raw.columns)
TFIDF
# Out:
#               aa       aaf     aaron     ababa  abandoned  abandonment  \
# mag_id
# 0       0.000000  0.000000  0.000000  0.000000   0.000000     0.021819
# 1       0.000000  0.000000  0.009896  0.000000   0.000000     0.000000
# 2       0.000000  0.000000  0.000000  0.000000   0.014858     0.000000
# 3       0.034972  0.022065  0.000000  0.000000   0.000000     0.000000
# 4       0.000000  0.000000  0.000000  0.000000   0.000000     0.000000
# 5       0.000000  0.000000  0.000000  0.021334   0.000000     0.000000
# 6       0.000000  0.000000  0.019344  0.000000   0.000000     0.000000
# 7       0.000000  0.000000  0.027047  0.000000   0.000000     0.000000
# 8       0.000000  0.000000  0.009623  0.000000   0.016903     0.000000
# 9       0.000000  0.000000  0.000000  0.000000   0.000000     0.000000
#
#           abbott       abc    abclou  abcparamount  ...    zoomed   zooming  \
# mag_id                                              ...
# 0       0.000000  0.006568  0.000000      0.000000  ...  0.000000  0.000000
# 1       0.000000  0.007486  0.000000      0.000000  ...  0.000000  0.000000
# 2       0.021258  0.010142  0.000000      0.000000  ...  0.000000  0.000000
# 3       0.000000  0.019926  0.000000      0.000000  ...  0.000000  0.022065
# 4       0.000000  0.017678  0.022718      0.000000  ...  0.000000  0.000000
# 5       0.000000  0.000000  0.000000      0.000000  ...  0.000000  0.000000
# 6       0.000000  0.000000  0.000000      0.024305  ...  0.000000  0.000000
# 7       0.000000  0.000000  0.000000      0.000000  ...  0.000000  0.000000
# 8       0.000000  0.000000  0.000000      0.000000  ...  0.024183  0.000000
# 9       0.000000  0.000000  0.000000      0.000000  ...  0.000000  0.000000
#
#             zoot       zor        zs   zumwalt   zunicia    zuniga    zurich  \
# mag_id
# 0       0.000000  0.000000  0.021819  0.021819  0.000000  0.000000  0.000000
# 1       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3       0.000000  0.000000  0.000000  0.000000  0.022065  0.034972  0.000000
# 4       0.036007  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.015330
# 7       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.009634
# 8       0.000000  0.024183  0.000000  0.000000  0.000000  0.000000  0.009623
# 9       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.009300
#
#               zw
# mag_id
# 0       0.000000
# 1       0.000000
# 2       0.021258
# 3       0.000000
# 4       0.000000
# 5       0.000000
# 6       0.000000
# 7       0.000000
# 8       0.000000
# 9       0.000000
#
# [10 rows x 16287 columns]

# %% [markdown]
# # PCA Models

# %% [markdown]
# ## Generating the Document Component Matrix

# %%
pca_engine = PCA(n_components=5)
DCM = pd.DataFrame(pca_engine.fit_transform(TFIDF), index=TFIDF.index)
DCM.columns = ['PC{}'.format(i) for i in DCM.columns]
DCM
# Out:
# /Users/aniyahmcwilliams/miniconda3/envs/ds6021/lib/python3.12/site-packages/sklearn/utils/extmath.py:350: RuntimeWarning: divide by zero encountered in matmul
#   Q, _ = normalizer(A @ Q)
# /Users/aniyahmcwilliams/miniconda3/envs/ds6021/lib/python3.12/site-packages/sklearn/utils/extmath.py:350: RuntimeWarning: overflow encountered in matmul
#   Q, _ = normalizer(A @ Q)
# /Users/aniyahmcwilliams/miniconda3/envs/ds6021/lib/python3.12/site-packages/sklearn/utils/extmath.py:350: RuntimeWarning: invalid value encountered in matmul
#   Q, _ = normalizer(A @ Q)
# /Users/aniyahmcwilliams/miniconda3/envs/ds6021/lib/python3.12/site-packages/sklearn/utils/extmath.py:351: RuntimeWarning: divide by zero encountered in matmul
#   Q, _ = normalizer(A.T @ Q)
# /Users/aniyahmcwilliams/miniconda3/envs/ds6021/lib/python3.12/site-packages/sklearn/utils/extmath.py:351: RuntimeWarning: overflow encountered in matmul
#   Q, _ = normalizer(A.T @ Q)
# /Users/aniyahmcwilliams/miniconda3/envs/ds6021/lib/python3.12/site-packages/sklearn/utils/extmath.py:351: RuntimeWarning: invalid value encountered in matmul
#   Q, _ = normalizer(A.T @ Q)
# /Users/aniyahmcwilliams/miniconda3/envs/ds6021/lib/python3.12/site-packages/sklearn/utils/extmath.py:355: RuntimeWarning: divide by zero encountered in matmul
#   Q, _ = qr_normalizer(A @ Q)
# /Users/aniyahmcwilliams/miniconda3/envs/ds6021/lib/python3.12/site-packages/sklearn/utils/extmath.py:355: RuntimeWarning: overflow encountered in matmul
#   Q, _ = qr_normalizer(A @ Q)
# /Users/aniyahmcwilliams/miniconda3/envs/ds6021/lib/python3.12/site-packages/sklearn/utils/extmath.py:355: RuntimeWarning: invalid value encountered in matmul
#   Q, _ = qr_normalizer(A @ Q)
# /Users/aniyahmcwilliams/miniconda3/envs/ds6021/lib/python3.12/site-packages/sklearn/utils/extmath.py:577: RuntimeWarning: divide by zero encountered in matmul
#   B = Q.T @ M
# /Users/aniyahmcwilliams/miniconda3/envs/ds6021/lib/python3.12/site-packages/sklearn/utils/extmath.py:577: RuntimeWarning: overflow encountered in matmul
#   B = Q.T @ M
# /Users/aniyahmcwilliams/miniconda3/envs/ds6021/lib/python3.12/site-packages/sklearn/utils/extmath.py:577: RuntimeWarning: invalid value encountered in matmul
#   B = Q.T @ M
# /Users/aniyahmcwilliams/miniconda3/envs/ds6021/lib/python3.12/site-packages/sklearn/utils/extmath.py:590: RuntimeWarning: divide by zero encountered in matmul
#   U = Q @ Uhat
# /Users/aniyahmcwilliams/miniconda3/envs/ds6021/lib/python3.12/site-packages/sklearn/utils/extmath.py:590: RuntimeWarning: overflow encountered in matmul
#   U = Q @ Uhat
# /Users/aniyahmcwilliams/miniconda3/envs/ds6021/lib/python3.12/site-packages/sklearn/utils/extmath.py:590: RuntimeWarning: invalid value encountered in matmul
#   U = Q @ Uhat
#              PC0       PC1       PC2       PC3       PC4
# mag_id
# 0       0.266477  0.274879  0.244076 -0.381978  0.091360
# 1       0.108436  0.561769  0.330515  0.539125  0.162554
# 2       0.334209 -0.108963 -0.046076 -0.471029  0.458573
# 3       0.449811 -0.228586 -0.190436  0.134150 -0.369947
# 4       0.376961 -0.141726 -0.249879  0.272159 -0.177833
# 5      -0.227336 -0.549309  0.676278  0.037572 -0.130730
# 6      -0.352889  0.310087 -0.015282 -0.281249 -0.296676
# 7      -0.343959 -0.080929 -0.349447  0.053916  0.158583
# 8      -0.294330  0.147320 -0.188503 -0.149997 -0.373646
# 9      -0.317378 -0.184543 -0.211246  0.247330  0.477763

# %% [markdown]
# The number of components is 5.

# %% [markdown]
# # Component Term Matrix

# %%
COMPS = pd.DataFrame(pca_engine.components_.T * np.sqrt(pca_engine.explained_variance_))
COMPS.columns = ["PC{}".format(i) for i in COMPS.columns]
COMPS.index = TFIDF.columns
COMPS.index.name = 'term_str'
COMPS.T
# Out:
# term_str        aa       aaf     aaron     ababa  abandoned  abandonment  \
# PC0       0.005190  0.003274 -0.005902 -0.001600  -0.000003     0.001918
# PC1      -0.002755 -0.001738  0.003717 -0.004039   0.000300     0.002067
# PC2      -0.002303 -0.001453 -0.002866  0.004988  -0.001338     0.001841
# PC3       0.001633  0.001030 -0.000032  0.000279  -0.003318    -0.002900
# PC4      -0.004517 -0.002850 -0.001200 -0.000974   0.000174     0.000696
#
# term_str    abbott       abc    abclou  abcparamount  ...    zoomed   zooming  \
# PC0       0.002344  0.007119  0.002825     -0.002830  ... -0.002348  0.003274
# PC1      -0.000798 -0.000743 -0.001110      0.002597  ...  0.001228 -0.001738
# PC2      -0.000339 -0.001591 -0.001963     -0.000128  ... -0.001576 -0.001453
# PC3      -0.003484  0.001473  0.002152     -0.002379  ... -0.001262  0.001030
# PC4       0.003403 -0.001413 -0.001410     -0.002517  ... -0.003155 -0.002850
#
# term_str      zoot       zor        zs   zumwalt   zunicia    zuniga  \
# PC0       0.004478 -0.002348  0.001918  0.001918  0.003274  0.005190
# PC1      -0.001759  0.001228  0.002067  0.002067 -0.001738 -0.002755
# PC2      -0.003111 -0.001576  0.001841  0.001841 -0.001453 -0.002303
# PC3       0.003410 -0.001262 -0.002900 -0.002900  0.001030  0.001633
# PC4      -0.002235 -0.003155  0.000696  0.000696 -0.002850 -0.004517
#
# term_str    zurich        zw
# PC0      -0.004786  0.002344
# PC1       0.001267 -0.000798
# PC2      -0.002551 -0.000339
# PC3      -0.001021 -0.003484
# PC4      -0.000759  0.003403
#
# [5 rows x 16287 columns]

# %% [markdown]
# ### Getting the top 5 positive and negative terms

# %%
top_terms_sk = {}
data = []
for i in range(5):
    for j in [0, 1]:
        data.append((i, j, ' '.join(COMPS.sort_values(f'PC{i}', ascending=bool(j)).head(10).index.to_list())))
comp_strs = pd.DataFrame(data)
comp_strs.columns =  ['pc', 'pole', 'gloss']
comp_strs = comp_strs.set_index(['pc', 'pole'])
comp_strs.unstack()
# Out:
#                                                   gloss  \
# pole                                                  0
# pc
# 0     blacks reggie ali mg ms hurley percent granada...
# 1     bavasi tornado edgerton supremes weston witch ...
# 2     jelly dressen suicides cicero pichon mccarthy ...
# 3     bavasi tornado edgerton wills kodak weston wit...
# 4     granada tito cerda sx deedee ashe khalilah taj...
#
#
# pole                                                  1
# pc
# 0     dinah satchel lunch wealthy ark mccollum doby ...
# 1     jelly dressen suicides ethiopians manson mccar...
# 2     mccollum ye collie nkrumah doby insane bassey ...
# 3     granada sx deedee ashe tolbert taj khalilah ne...
# 4     dinah reggie hurley bodenheimer hula hawaiian ...

# %% [markdown]
# # PCA Visualization 1: first two components

# %%
LIB
# Out:
#              epub_id        date  \
# mag_id
# 0       vo8DAAAAMBAJ  1972-12-07
# 1       ProDAAAAMBAJ  1967-05-11
# 2       dEIDAAAAMBAJ  1975-11-20
# 3       YEIDAAAAMBAJ  1978-05-04
# 4       AMADAAAAMBAJ  1978-07-06
# 5       JEMDAAAAMBAJ  1951-11-01
# 6       vq8DAAAAMBAJ  1960-03-10
# 7       fbcDAAAAMBAJ  1958-02-20
# 8       YkEDAAAAMBAJ  1959-08-20
# 9       mEEDAAAAMBAJ  1959-04-09
#
#                                                     pages  month      quarter  \
# mag_id
# 0       ["\n\n\n\nThis book was produced in EPUB forma...     12  4th Quarter
# 1       ["\n\n\n\nThis book was produced in EPUB forma...      5  2nd Quarter
# 2       ["\n\n\n\nThis book was produced in EPUB forma...     11  4th Quarter
# 3       ["\n\n\n\nThis book was produced in EPUB forma...      5  2nd Quarter
# 4       ["\n\n\n\nThis book was produced in EPUB forma...      7  3rd Quarter
# 5       ["\n\n\n\nThis book was produced in EPUB forma...     11  4th Quarter
# 6       ["\n\n\n\nThis book was produced in EPUB forma...      3  1st Quarter
# 7       ["\n\n\n\nThis book was produced in EPUB forma...      2  1st Quarter
# 8       ["\n\n\n\nThis book was produced in EPUB forma...      8  3rd Quarter
# 9       ["\n\n\n\nThis book was produced in EPUB forma...      4  2nd Quarter
#
#         page_num                                              title  \
# mag_id
# 0             68  What Dope Arrest is Doing to Career of Barbara...
# 1             68        What's Behind Suicide of Charles Diggs Sr.?
# 2             68             Tito Jackson: His Music and His Family
# 3             68                  New Reggie Defends His Hero Image
# 4             68                 Benson Shares His Fame With Family
# 5             68  Ten Ways to Get a Mink Coat/ Why Negro Suicide...
# 6             68  How Negroes Feel about a Catholic for US Presi...
# 7             68  Rudy McCollum Talks Ends 5-Year Silence in Ins...
# 8             68  First Poll Reveals Candidates Negroes Want for...
# 9             68  Why Cuban Rebels Jailed Son of Wealthy Negro /...
#
#         character_len
# mag_id
# 0               99374
# 1               74986
# 2               89009
# 3               85341
# 4               89396
# 5               81741
# 6               79252
# 7               74909
# 8               78302
# 9               76401

# %%
def vis_pcs(DCM, a, b, label = 'quarter', hover_name='title'):
    return px.scatter(DCM, f"PC{a}", f"PC{b}",  
                    color=LIB[label],
                    hover_name=LIB[hover_name], 
                    size=LIB['character_len'],
                    marginal_x='box', height=800)
    
def vis_loadings(COMPS, a=0, b=1, hover_name='term_str'):
    return px.scatter(COMPS.reset_index(), f"PC{a}", f"PC{b}", 
                      text='term_str', 
                      marginal_x='box', 
                      height=800)

# %%
vis_pcs(DCM, 0, 1)

# %%
vis_loadings(COMPS, 0, 1)

# %% [markdown]
# # PCA Visualization 2

# %%
vis_pcs(DCM, 1, 2)

# %%
vis_loadings(COMPS, 1, 2)

# %% [markdown]
# # LDA Models

# %%
# importing the necessary packages 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation as LDA, NMF 
from sklearn.feature_extraction import text

# %%
# first going to read in corpus data frame 
OHCO = ['mag_id', 'page_num','token_num']
SENTENCE = OHCO[:2],
MAGAZINE = OHCO[:1]
BAG = MAGAZINE
TOKENS = pd.read_csv('/Users/aniyahmcwilliams/Spring 2026/Text As Data/final project/DATA/CORPUS.csv', index_col=['mag_id','page_num','token_num'])
TOKENS.head()
# Out:
#                           pos pos_group token_str term_str
# mag_id page_num token_num
# 0      1        0          DT        DT       The      the
#                 1          NN        NN      text     text
#                 2          IN        IN        on       on
#                 3          DT        DT      this     this
#                 4          NN        NN      page     page

# %%
# converting the tokens table back to DOC style
DOCS = TOKENS[TOKENS.pos.str.match(r'^NNS?$')]\
    .groupby(BAG).term_str\
    .apply(lambda x: ' '.join(map(str,x)))\
    .to_frame()\
    .rename(columns={'term_str':'doc_str'})
DOCS
# Out:
#                                                   doc_str
# mag_id
# 0       text page kl ll ll warning jmgsr jvm editor ph...
# 1       kissiri cousin friendship taste goodbye flfi w...
# 2       elevator pack pack editor photo story page off...
# 3       tar lot air coolness coolness kind refreshment...
# 4       taste smoke taste taste cigarette doesn taste ...
# 5       role night show year farm ess indictments negr...
# 6       graduate opinions whiz kid basketball records ...
# 7       model styles swim suits news pictures week wee...
# 8       lawyer state message brilliant leader message ...
# 9       week mail issues words widow man guests honor ...

# %% [markdown]
# # Creating the Vector Space

# %%
my_stop_words = list(text.ENGLISH_STOP_WORDS.union(['yes']))

# %%
count_engine = CountVectorizer(min_df=.9,stop_words=my_stop_words) # had to change the settings, this is saying a term must appear in at least 90% of documents (9/10 of the magazines)
count_model = count_engine.fit_transform(DOCS.doc_str)
TERMS = count_engine.get_feature_names_out()
VOCAB = pd.DataFrame(index=TERMS)
VOCAB.index.name = 'term_str'
DTM = pd.DataFrame(count_model.toarray(), index=DOCS.index, columns=TERMS)
DTM
# Out:
#         action  actor  appeal  area  areas  assistant  attack  attempt  \
# mag_id
# 0            2      1       1     3      2         10       3        1
# 1            3      1       1     5      3          5       3        2
# 2            2      2       3     2      1          5       2        0
# 3            1      2       3     3      3          3       2        1
# 4            0      1       2     2      5          4       0        1
# 5            3      2       3     1      3          2       3        2
# 6            7      2       1     4      2          4       4        1
# 7            3      2       1     1      2          2       3        1
# 8            3      1       1     6      0          1       6        1
# 9            4      1       0     1      1          3       1        1
#
#         attorney  award  ...  whites  wife  woman  women  words  work  worker  \
# mag_id                   ...
# 0              3      2  ...       7     4      5      6      3     1       1
# 1              1      0  ...       4     3      3      8      1     3       2
# 2              4      2  ...       0    20      8      8      3     6       1
# 3              2      4  ...       3    16     15     13      1     5       1
# 4              3      2  ...       3    13      6      6      4     3       1
# 5              2      1  ...       7    23     15     24      3     4       1
# 6              4      2  ...       4    22      4      8      2     3       5
# 7              1      1  ...       7    23     11      8      2     9       1
# 8              2      1  ...       4    15      9      3      1     2       0
# 9              5      3  ...       2    17     13      5      3     3       1
#
#         world  year  years
# mag_id
# 0           9    13     27
# 1           6    14     22
# 2           9    15     19
# 3           4    18     31
# 4          12    21     23
# 5           9    15     32
# 6           2    11     20
# 7           7    13     25
# 8           3    11     17
# 9           7    18     27
#
# [10 rows x 191 columns]

# %% [markdown]
# # Generating the Model

# %%
n_topics = 10
max_iter = 100
n_top_terms = 5
TNAMES = [f"T{str(x).zfill(len(str(n_topics)))}" for x in range(n_topics)]
topic_engine = LDA(n_components=n_topics, max_iter=max_iter)
topic_model = topic_engine.fit_transform(count_model)

# %% [markdown]
# ## Calculating THETA

# %%
THETA = pd.DataFrame(topic_model, index=DOCS.index, columns=TNAMES)
THETA.columns.name = 'topic_id'
THETA.sample(10).T.style.background_gradient(axis=None)
# Out:
# <style type="text/css">
# #T_3e73a_row0_col0, #T_3e73a_row0_col1, #T_3e73a_row0_col2, #T_3e73a_row0_col3, #T_3e73a_row0_col4, #T_3e73a_row0_col5, #T_3e73a_row0_col6, #T_3e73a_row0_col7, #T_3e73a_row0_col8, #T_3e73a_row0_col9, #T_3e73a_row1_col0, #T_3e73a_row1_col1, #T_3e73a_row1_col2, #T_3e73a_row1_col3, #T_3e73a_row1_col4, #T_3e73a_row1_col5, #T_3e73a_row1_col6, #T_3e73a_row1_col7, #T_3e73a_row1_col8, #T_3e73a_row1_col9, #T_3e73a_row2_col0, #T_3e73a_row2_col1, #T_3e73a_row2_col2, #T_3e73a_row2_col3, #T_3e73a_row2_col4, #T_3e73a_row2_col5, #T_3e73a_row2_col6, #T_3e73a_row2_col8, #T_3e73a_row2_col9, #T_3e73a_row4_col0, #T_3e73a_row4_col1, #T_3e73a_row4_col2, #T_3e73a_row4_col4, #T_3e73a_row4_col5, #T_3e73a_row4_col6, #T_3e73a_row4_col7, #T_3e73a_row4_col8, #T_3e73a_row4_col9, #T_3e73a_row5_col0, #T_3e73a_row5_col1, #T_3e73a_row5_col2, #T_3e73a_row5_col3, #T_3e73a_row5_col4, #T_3e73a_row5_col5, #T_3e73a_row5_col6, #T_3e73a_row5_col7, #T_3e73a_row5_col8, #T_3e73a_row5_col9, #T_3e73a_row6_col0, #T_3e73a_row6_col1, #T_3e73a_row6_col2, #T_3e73a_row6_col3, #T_3e73a_row6_col4, #T_3e73a_row6_col5, #T_3e73a_row6_col6, #T_3e73a_row6_col7, #T_3e73a_row6_col8, #T_3e73a_row6_col9, #T_3e73a_row7_col1, #T_3e73a_row7_col2, #T_3e73a_row7_col3, #T_3e73a_row7_col4, #T_3e73a_row7_col5, #T_3e73a_row7_col6, #T_3e73a_row7_col7, #T_3e73a_row7_col8, #T_3e73a_row7_col9, #T_3e73a_row8_col0, #T_3e73a_row8_col1, #T_3e73a_row8_col2, #T_3e73a_row8_col3, #T_3e73a_row8_col4, #T_3e73a_row8_col5, #T_3e73a_row8_col7, #T_3e73a_row8_col8, #T_3e73a_row8_col9, #T_3e73a_row9_col0, #T_3e73a_row9_col1, #T_3e73a_row9_col2, #T_3e73a_row9_col3, #T_3e73a_row9_col5, #T_3e73a_row9_col6, #T_3e73a_row9_col7, #T_3e73a_row9_col8, #T_3e73a_row9_col9 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_3e73a_row2_col7 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_3e73a_row3_col0 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_3e73a_row3_col1, #T_3e73a_row3_col2, #T_3e73a_row3_col5, #T_3e73a_row3_col8, #T_3e73a_row3_col9 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_3e73a_row3_col3 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_3e73a_row3_col4 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_3e73a_row3_col6 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_3e73a_row3_col7 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_3e73a_row4_col3 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_3e73a_row7_col0 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_3e73a_row8_col6 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_3e73a_row9_col4 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# </style>
# <table id="T_3e73a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >mag_id</th>
#       <th id="T_3e73a_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_3e73a_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_3e73a_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_3e73a_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_3e73a_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_3e73a_level0_col5" class="col_heading level0 col5" >9</th>
#       <th id="T_3e73a_level0_col6" class="col_heading level0 col6" >8</th>
#       <th id="T_3e73a_level0_col7" class="col_heading level0 col7" >5</th>
#       <th id="T_3e73a_level0_col8" class="col_heading level0 col8" >6</th>
#       <th id="T_3e73a_level0_col9" class="col_heading level0 col9" >7</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e73a_level0_row0" class="row_heading level0 row0" >T00</th>
#       <td id="T_3e73a_row0_col0" class="data row0 col0" >0.000110</td>
#       <td id="T_3e73a_row0_col1" class="data row0 col1" >0.000146</td>
#       <td id="T_3e73a_row0_col2" class="data row0 col2" >0.000130</td>
#       <td id="T_3e73a_row0_col3" class="data row0 col3" >0.000124</td>
#       <td id="T_3e73a_row0_col4" class="data row0 col4" >0.000122</td>
#       <td id="T_3e73a_row0_col5" class="data row0 col5" >0.000137</td>
#       <td id="T_3e73a_row0_col6" class="data row0 col6" >0.000132</td>
#       <td id="T_3e73a_row0_col7" class="data row0 col7" >0.000118</td>
#       <td id="T_3e73a_row0_col8" class="data row0 col8" >0.000127</td>
#       <td id="T_3e73a_row0_col9" class="data row0 col9" >0.000128</td>
#     </tr>
#     <tr>
#       <th id="T_3e73a_level0_row1" class="row_heading level0 row1" >T01</th>
#       <td id="T_3e73a_row1_col0" class="data row1 col0" >0.000110</td>
#       <td id="T_3e73a_row1_col1" class="data row1 col1" >0.000146</td>
#       <td id="T_3e73a_row1_col2" class="data row1 col2" >0.000130</td>
#       <td id="T_3e73a_row1_col3" class="data row1 col3" >0.000124</td>
#       <td id="T_3e73a_row1_col4" class="data row1 col4" >0.000122</td>
#       <td id="T_3e73a_row1_col5" class="data row1 col5" >0.000137</td>
#       <td id="T_3e73a_row1_col6" class="data row1 col6" >0.000132</td>
#       <td id="T_3e73a_row1_col7" class="data row1 col7" >0.000118</td>
#       <td id="T_3e73a_row1_col8" class="data row1 col8" >0.000127</td>
#       <td id="T_3e73a_row1_col9" class="data row1 col9" >0.000128</td>
#     </tr>
#     <tr>
#       <th id="T_3e73a_level0_row2" class="row_heading level0 row2" >T02</th>
#       <td id="T_3e73a_row2_col0" class="data row2 col0" >0.000110</td>
#       <td id="T_3e73a_row2_col1" class="data row2 col1" >0.000146</td>
#       <td id="T_3e73a_row2_col2" class="data row2 col2" >0.000130</td>
#       <td id="T_3e73a_row2_col3" class="data row2 col3" >0.000124</td>
#       <td id="T_3e73a_row2_col4" class="data row2 col4" >0.000122</td>
#       <td id="T_3e73a_row2_col5" class="data row2 col5" >0.000137</td>
#       <td id="T_3e73a_row2_col6" class="data row2 col6" >0.000132</td>
#       <td id="T_3e73a_row2_col7" class="data row2 col7" >0.137334</td>
#       <td id="T_3e73a_row2_col8" class="data row2 col8" >0.000127</td>
#       <td id="T_3e73a_row2_col9" class="data row2 col9" >0.000128</td>
#     </tr>
#     <tr>
#       <th id="T_3e73a_level0_row3" class="row_heading level0 row3" >T03</th>
#       <td id="T_3e73a_row3_col0" class="data row3 col0" >0.762360</td>
#       <td id="T_3e73a_row3_col1" class="data row3 col1" >0.998684</td>
#       <td id="T_3e73a_row3_col2" class="data row3 col2" >0.998834</td>
#       <td id="T_3e73a_row3_col3" class="data row3 col3" >0.822514</td>
#       <td id="T_3e73a_row3_col4" class="data row3 col4" >0.719936</td>
#       <td id="T_3e73a_row3_col5" class="data row3 col5" >0.998764</td>
#       <td id="T_3e73a_row3_col6" class="data row3 col6" >0.781474</td>
#       <td id="T_3e73a_row3_col7" class="data row3 col7" >0.861724</td>
#       <td id="T_3e73a_row3_col8" class="data row3 col8" >0.998858</td>
#       <td id="T_3e73a_row3_col9" class="data row3 col9" >0.998849</td>
#     </tr>
#     <tr>
#       <th id="T_3e73a_level0_row4" class="row_heading level0 row4" >T04</th>
#       <td id="T_3e73a_row4_col0" class="data row4 col0" >0.000110</td>
#       <td id="T_3e73a_row4_col1" class="data row4 col1" >0.000146</td>
#       <td id="T_3e73a_row4_col2" class="data row4 col2" >0.000130</td>
#       <td id="T_3e73a_row4_col3" class="data row4 col3" >0.176493</td>
#       <td id="T_3e73a_row4_col4" class="data row4 col4" >0.000122</td>
#       <td id="T_3e73a_row4_col5" class="data row4 col5" >0.000137</td>
#       <td id="T_3e73a_row4_col6" class="data row4 col6" >0.000132</td>
#       <td id="T_3e73a_row4_col7" class="data row4 col7" >0.000118</td>
#       <td id="T_3e73a_row4_col8" class="data row4 col8" >0.000127</td>
#       <td id="T_3e73a_row4_col9" class="data row4 col9" >0

# %% [markdown]
# # Calculating PHI

# %%
PHI = pd.DataFrame(topic_engine.components_, columns=TERMS, index=TNAMES)
PHI.index.name = 'topic_id'
PHI.columns.name = 'term_str'
PHI.T.sample(10).T.style.background_gradient(axis=None)
# Out:
# <style type="text/css">
# #T_e90c6_row0_col0, #T_e90c6_row0_col1, #T_e90c6_row0_col2, #T_e90c6_row0_col3, #T_e90c6_row0_col4, #T_e90c6_row0_col5, #T_e90c6_row0_col6, #T_e90c6_row0_col7, #T_e90c6_row0_col8, #T_e90c6_row0_col9, #T_e90c6_row1_col0, #T_e90c6_row1_col1, #T_e90c6_row1_col2, #T_e90c6_row1_col3, #T_e90c6_row1_col4, #T_e90c6_row1_col5, #T_e90c6_row1_col6, #T_e90c6_row1_col7, #T_e90c6_row1_col8, #T_e90c6_row1_col9, #T_e90c6_row2_col0, #T_e90c6_row2_col1, #T_e90c6_row2_col2, #T_e90c6_row2_col3, #T_e90c6_row2_col4, #T_e90c6_row2_col6, #T_e90c6_row2_col7, #T_e90c6_row2_col8, #T_e90c6_row2_col9, #T_e90c6_row4_col0, #T_e90c6_row4_col1, #T_e90c6_row4_col2, #T_e90c6_row4_col3, #T_e90c6_row4_col4, #T_e90c6_row4_col6, #T_e90c6_row4_col7, #T_e90c6_row4_col8, #T_e90c6_row4_col9, #T_e90c6_row5_col0, #T_e90c6_row5_col1, #T_e90c6_row5_col2, #T_e90c6_row5_col3, #T_e90c6_row5_col4, #T_e90c6_row5_col5, #T_e90c6_row5_col6, #T_e90c6_row5_col7, #T_e90c6_row5_col8, #T_e90c6_row5_col9, #T_e90c6_row6_col0, #T_e90c6_row6_col1, #T_e90c6_row6_col2, #T_e90c6_row6_col3, #T_e90c6_row6_col4, #T_e90c6_row6_col5, #T_e90c6_row6_col6, #T_e90c6_row6_col7, #T_e90c6_row6_col8, #T_e90c6_row6_col9, #T_e90c6_row7_col0, #T_e90c6_row7_col2, #T_e90c6_row7_col4, #T_e90c6_row7_col5, #T_e90c6_row7_col6, #T_e90c6_row7_col7, #T_e90c6_row7_col8, #T_e90c6_row7_col9, #T_e90c6_row8_col0, #T_e90c6_row8_col1, #T_e90c6_row8_col2, #T_e90c6_row8_col3, #T_e90c6_row8_col4, #T_e90c6_row8_col5, #T_e90c6_row8_col6, #T_e90c6_row8_col7, #T_e90c6_row8_col8, #T_e90c6_row9_col2, #T_e90c6_row9_col3, #T_e90c6_row9_col4, #T_e90c6_row9_col5, #T_e90c6_row9_col6, #T_e90c6_row9_col7, #T_e90c6_row9_col8, #T_e90c6_row9_col9 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_e90c6_row2_col5 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_e90c6_row3_col0 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_e90c6_row3_col1 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_e90c6_row3_col2 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_e90c6_row3_col3 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_e90c6_row3_col4 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_e90c6_row3_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e90c6_row3_col6 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_e90c6_row3_col7 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_e90c6_row3_col8 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_e90c6_row3_col9 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_e90c6_row4_col5, #T_e90c6_row7_col3 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_e90c6_row7_col1 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_e90c6_row8_col9 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_e90c6_row9_col0, #T_e90c6_row9_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# </style>
# <table id="T_e90c6">
#   <thead>
#     <tr>
#       <th class="index_name level0" >term_str</th>
#       <th id="T_e90c6_level0_col0" class="col_heading level0 col0" >house</th>
#       <th id="T_e90c6_level0_col1" class="col_heading level0 col1" >nation</th>
#       <th id="T_e90c6_level0_col2" class="col_heading level0 col2" >court</th>
#       <th id="T_e90c6_level0_col3" class="col_heading level0 col3" >chairman</th>
#       <th id="T_e90c6_level0_col4" class="col_heading level0 col4" >love</th>
#       <th id="T_e90c6_level0_col5" class="col_heading level0 col5" >women</th>
#       <th id="T_e90c6_level0_col6" class="col_heading level0 col6" >publication</th>
#       <th id="T_e90c6_level0_col7" class="col_heading level0 col7" >work</th>
#       <th id="T_e90c6_level0_col8" class="col_heading level0 col8" >look</th>
#       <th id="T_e90c6_level0_col9" class="col_heading level0 col9" >rights</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e90c6_level0_row0" class="row_heading level0 row0" >T00</th>
#       <td id="T_e90c6_row0_col0" class="data row0 col0" >0.100000</td>
#       <td id="T_e90c6_row0_col1" class="data row0 col1" >0.100000</td>
#       <td id="T_e90c6_row0_col2" class="data row0 col2" >0.100000</td>
#       <td id="T_e90c6_row0_col3" class="data row0 col3" >0.100000</td>
#       <td id="T_e90c6_row0_col4" class="data row0 col4" >0.100000</td>
#       <td id="T_e90c6_row0_col5" class="data row0 col5" >0.100000</td>
#       <td id="T_e90c6_row0_col6" class="data row0 col6" >0.100000</td>
#       <td id="T_e90c6_row0_col7" class="data row0 col7" >0.100000</td>
#       <td id="T_e90c6_row0_col8" class="data row0 col8" >0.100000</td>
#       <td id="T_e90c6_row0_col9" class="data row0 col9" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_e90c6_level0_row1" class="row_heading level0 row1" >T01</th>
#       <td id="T_e90c6_row1_col0" class="data row1 col0" >0.100000</td>
#       <td id="T_e90c6_row1_col1" class="data row1 col1" >0.100000</td>
#       <td id="T_e90c6_row1_col2" class="data row1 col2" >0.100000</td>
#       <td id="T_e90c6_row1_col3" class="data row1 col3" >0.100000</td>
#       <td id="T_e90c6_row1_col4" class="data row1 col4" >0.100000</td>
#       <td id="T_e90c6_row1_col5" class="data row1 col5" >0.100000</td>
#       <td id="T_e90c6_row1_col6" class="data row1 col6" >0.100000</td>
#       <td id="T_e90c6_row1_col7" class="data row1 col7" >0.100000</td>
#       <td id="T_e90c6_row1_col8" class="data row1 col8" >0.100000</td>
#       <td id="T_e90c6_row1_col9" class="data row1 col9" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_e90c6_level0_row2" class="row_heading level0 row2" >T02</th>
#       <td id="T_e90c6_row2_col0" class="data row2 col0" >0.100014</td>
#       <td id="T_e90c6_row2_col1" class="data row2 col1" >0.100030</td>
#       <td id="T_e90c6_row2_col2" class="data row2 col2" >0.100037</td>
#       <td id="T_e90c6_row2_col3" class="data row2 col3" >0.100008</td>
#       <td id="T_e90c6_row2_col4" class="data row2 col4" >0.100031</td>
#       <td id="T_e90c6_row2_col5" class="data row2 col5" >15.683382</td>
#       <td id="T_e90c6_row2_col6" class="data row2 col6" >0.100055</td>
#       <td id="T_e90c6_row2_col7" class="data row2 col7" >0.100026</td>
#       <td id="T_e90c6_row2_col8" class="data row2 col8" >0.100053</td>
#       <td id="T_e90c6_row2_col9" class="data row2 col9" >0.100022</td>
#     </tr>
#     <tr>
#       <th id="T_e90c6_level0_row3" class="row_heading level0 row3" >T03</th>
#       <td id="T_e90c6_row3_col0" class="data row3 col0" >34.589912</td>
#       <td id="T_e90c6_row3_col1" class="data row3 col1" >50.257155</td>
#       <td id="T_e90c6_row3_col2" class="data row3 col2" >61.099860</td>
#       <td id="T_e90c6_row3_col3" class="data row3 col3" >32.829079</td>
#       <td id="T_e90c6_row3_col4" class="data row3 col4" >24.099876</td>
#       <td id="T_e90c6_row3_col5" class="data row3 col5" >68.352579</td>
#       <td id="T_e90c6_row3_col6" class="data row3 col6" >14.099856</td>
#       <td id="T_e90c6_row3_col7" class="data row3 col7" >39.099889</td>
#       <td id="T_e90c6_row3_col8" class="data row3 col8" >19.099845</td>
#       <td id="T_e90c6_row3_col9" class="data row3 col9" >55.688377</td>
#     </tr>
#     <tr>
#       <th id="T_e90c6_level0_row4" class="row_heading level0 row4" >T04</th>
#       <td id="T_e90c6_row4_col0" class="data row4 col0" >0.100033</td>
#       <td id="T_e90c6_row4_col1" class="data row4 col1" >0.100039</td>
#       <td id="T_e90c6_row4_col2" class="data row4 col2" >0.100014</td>
#       <td id="T_e90c6_row4_col3" class="data row4 col3" >0.100026</td>
#       <td id="T_e90c6_row4_col4" class="data row4 col4" >0.100024</td>
#       <td id="T_e90c6_row4_col5" class="data row4 col5" >5.263971</td>
#       <td

# %% [markdown]
# # Getting the Topics

# %%
TOPICS = PHI.stack().groupby('topic_id')\
    .apply(lambda x: ' '.join(x.sort_values(ascending=False).head(n_top_terms).reset_index().term_str))\
    .to_frame('top_terms')
TOPICS
# Out:
#                                         top_terms
# topic_id
# T00              staff attempt brothers town news
# T01              staff attempt brothers town news
# T02                     week women race star news
# T03                  years wife time man material
# T04               people music head time baseball
# T05              staff attempt brothers town news
# T06              staff attempt brothers town news
# T07       students office state president members
# T08                race leader end marriage girls
# T09               people music guests record city
